# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/session_27_reading_excel_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel('/content/CarsDrivenTillNow.xlsx', header=1)
# Out:
#     Serial No.          Brand           Model    Fuel Transmission
# 0            1  Maruti Suzuki             Zen  Petrol       Manual
# 1            2  Maruti Suzuki         Wagon R  Petrol       Manual
# 2            3  Maruti Suzuki         Wagon R     CNG       Manual
# 3            4  Maruti Suzuki           Swift  Diesel       Manual
# 4            5  Maruti Suzuki           Swift  Petrol       Manual
# 5            6         Nissan    Micra Active  Petrol       Manual
# 6            7            Kia          Seltos  Diesel       Manual
# 7            8           Tata           Tiago  Petrol       Manual
# 8            9           Tata  Tiago Facelift  Petrol       Manual
# 9           10       Hyundai         i20 Asta  Petrol       Manual
# 10          11       Hyundai             i20   Petrol       Manual
# 11          12         Toyota           Etios  Petrol       Manual
# 12          13           Tata           Nexon  Diesel       Manual
# ...

# %%
pd.read_excel('/content/CarsDrivenTillNow.xlsx', index_col='Serial No.', header = 1)
# Out:
#                     Brand           Model    Fuel Transmission
# Serial No.
# 1           Maruti Suzuki             Zen  Petrol       Manual
# 2           Maruti Suzuki         Wagon R  Petrol       Manual
# 3           Maruti Suzuki         Wagon R     CNG       Manual
# 4           Maruti Suzuki           Swift  Diesel       Manual
# 5           Maruti Suzuki           Swift  Petrol       Manual
# 6                  Nissan    Micra Active  Petrol       Manual
# 7                     Kia          Seltos  Diesel       Manual
# 8                    Tata           Tiago  Petrol       Manual
# 9                    Tata  Tiago Facelift  Petrol       Manual
# 10               Hyundai         i20 Asta  Petrol       Manual
# 11               Hyundai             i20   Petrol       Manual
# 12                 Toyota           Etios  Petrol       Manual
# 13                   Tata           Nexon  Diesel       Manual
# 14               Hyundai           Venue   Petrol    Automatic
# ...

# %%
pd.read_excel('/content/CarsDrivenTillNow.xlsx',sheet_name='Kiran')
# Out:
#   List of Cars Kiran has Driven     Unnamed: 1    Unnamed: 2 Unnamed: 3  \
# 0                    Serial No.          Brand         Model       Fuel
# 1                             1           Tata        Altroz     Petrol
# 2                             2  Maruti Suzuki  Swift Dezire        CNG
# 3                             3           Fiat         Linea     Petrol
#
#      Unnamed: 4
# 0  Transmission
# 1     Automatic
# 2        Manual
# 3        Manual

# %% [markdown]
# ### Reading text files

# %%
# pd.read_csv('question_answer_pairs.txt',sep='\t')
