# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/session_27_web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# # if response code is 403
#  - headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
#  -requests.get('url',headers=headers).text

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;aff10f17&#46;1763572158&#46;1fb57315\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;aff10f17&#46;1763572158&#46;1fb57315</P>\n</BODY>\n</HTML>\n'

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.ambitionbox.com/list-of-companies?" on this server.
#   <p>
#    Reference #18.aff10f17.1763572107.1fb4bddf
#   </p>
#   <p>
#    https://errors.edgesuite.net/18.aff10f17.1763572107.1fb4bddf
#   </p>
#  </body>
# </html>

# %%
soup.find_all('h1')[0].text
# Out:
# 'Access Denied'

# %% [markdown]
# # TO FIND OUT NAMES OF THE COMPANIES

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())

# %%
for i in soup.find_all('p'):
  print(i.text.strip())
# Out:
# Reference #18.aff10f17.1763571946.1fb272fc
# https://errors.edgesuite.net/18.aff10f17.1763571946.1fb272fc

# %%
for i in soup.find_all('p'):
  print(i.text.strip())
# Out:
# Reference #18.aff10f17.1763571946.1fb272fc
# https://errors.edgesuite.net/18.aff10f17.1763571946.1fb272fc

# %% [markdown]
# ## TO FIND OUT THE RATINGS

# %%
len(soup.find_all('p',class_='rating'))
# Out:
# 0

# %% [markdown]
# ## TO FIND OUT THE NUMBER OF REVIEWS

# %%
# len(soup.find_all('a' , class_='review-count'))

# %% [markdown]
# # CONSIDERING THE WHOLE CONTAINER

# %%
# company=soup.find_all('div',class_='company-content-wrapper')

# %%
# len(company)

# %%
# name=[]
# rating=[]
# reviews=[]
# ctype=[]
# hq=[]
# how_old=[]
# no_of_employee=[]

# for i in company:

#   name.append(i.find('h2').text.strip())
#   rating.append(i.find('p',class_='rating').text.strip())
#   reviews.append(i.find('a' , class_='review-count').text.strip())
#   ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
#   hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
#   how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
#   no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())

# df=pd.DataFrame({'name':name,
#    'rating':rating,
#    'reviews':reviews,
#    'company_type':ctype,
#    'Head_Quarters':hq,
#    'Company_Age':how_old,
#    'No_of_Employee':no_of_employee,
#    })

# %%
# name

# %%
# rating

# %%
# reviews

# %%
# ctype

# %%
# hq

# %%
# how_old

# %%
# no_of_employee
# Out:
# ['10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees']

# %%
# df.shape
# Out:
# (30, 7)

# %% [markdown]
# # creating dataframe for all the pages

# %%
final = pd.DataFrame()
for j in range(1, 1001):
    webpage = requests.get(f'https://www.ambitionbox.com/list-of-companies?page={j}').text
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div', class_='company-content-wrapper')

    name = []
    rating = []
    reviews = []
    ctype = []
    hq = []
    how_old = []
    no_of_employee = []

    for i in company:
        try:
            name.append(i.find('h2').text.strip())
        except:
            name.append(np.nan)

        try:
            rating.append(i.find('p', class_='rating').text.strip())
        except:
            rating.append(np.nan)

        try:
            reviews.append(i.find('a', class_='review-count').text.strip())
        except:
            reviews.append(np.nan)

        try:
            ctype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
        except:
            ctype.append(np.nan)

        try:
            hq.append(i.find_all('p', class_='infoEntity')[1].text.strip())
        except:
            hq.append(np.nan)

        try:
            how_old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
        except:
            how_old.append(np.nan)

        try:
            no_of_employee.append(i.find_all('p', class_='infoEntity')[3].text.strip())
        except:
            no_of_employee.append(np.nan)

    df = pd.DataFrame({
        'name': name,
        'rating': rating,
        'reviews': reviews,
        'company_type': ctype,
        'Head_Quarters': hq,
        'Company_Age': how_old,
        'No_of_Employee': no_of_employee,
    })

    final = pd.concat([final, df], ignore_index=True)

# %%
final
# Out:
# Empty DataFrame
# Columns: [name, rating, reviews, company_type, Head_Quarters, Company_Age, No_of_Employee]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [name, rating, reviews, company_type, Head_Quarters, Company_Age, No_of_Employee]
# Index: []

# %%
# df.shape
# Out:
# (30, 7)

# %%
# final.shape
# Out:
# (30000, 7)
