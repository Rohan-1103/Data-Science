# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/NLP/game_of_thrones_word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 79.3 MB/s eta 0:00:00
# ...

# %%
import gensim
import os
import nltk

# %%
from nltk import sent_tokenize
nltk.download('punkt_tab')
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('data'):

    f = open(os.path.join('data',filename), encoding='latin-1')
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
story
# Out:
# [['storm',
#   'of',
#   'swords',
#   'book',
#   'three',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george'],
#  ['martin',
#   'note',
#   'on',
#   'chronology',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'is',
#   'told',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'characters',
#   'who',
#   'are',
#   'sometimes',
#   'hundreds',
#   'or',
#   'even',
#   'thousands',
#   'of',
#   'miles',
#   'apart',
#   'from',
#   'one',
#   'another'],
#  ['some',
#   'chapters',
#   'cover',
#   'day',
#   'some',
#   'only',
#   'an',
#   'hour',
#   'others',
#   'might',
#   'span',
#   'fortnight',
#   'month',
#   'half',
#   'year'],
#  ['with',
#   'such',
#   'structure',
#   'the',
#   'narrative',
#   'cannot',
#   'be',
#   'strictly',
#   'sequential',
#   'sometimes',
#   'important',
#   'things',
#   'are',
#   'happening',
#   'simultaneously',
#   'thousand',
#   'leagues',
#   'apart'],
#  ['in',
# ...

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6568886, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8007856011390686),
#  ('targaryen', 0.7450655698776245),
#  ('queen', 0.713306725025177),
#  ('viserys', 0.6972264647483826),
#  ('unburnt', 0.6910731196403503),
#  ('margaery', 0.6650755405426025),
#  ('dorne', 0.6646614074707031),
#  ('myrcella', 0.6554663181304932),
#  ('princess', 0.650280773639679),
#  ('westeros', 0.6495433449745178)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# WARNING:gensim.models.keyedvectors:vectors for words {'rikon'} are not present in the model, ignoring these words
# 'jon'

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'

# %%
model.wv['king']
# Out:
# array([ 0.28633282,  0.5815345 ,  0.69700587,  1.544441  , -3.1305401 ,
#        -0.8314965 ,  0.7298623 ,  2.8139184 , -0.61965996,  0.31128243,
#        -2.1900308 , -1.4449149 , -0.8677004 ,  1.4880954 , -2.4834967 ,
#        -3.3488648 , -0.26968735,  1.4010534 ,  0.8115299 , -1.2471589 ,
#         0.68668085,  0.68984306,  3.2365646 , -2.0946736 , -1.3362075 ,
#        -0.634932  , -2.389252  , -0.09166814, -1.8296888 ,  1.1059151 ,
#        -0.63752055,  2.3850205 ,  0.40503386, -0.01564134,  0.96178836,
#        -1.5406687 , -2.6913357 ,  0.81811845,  1.0994185 , -2.268493  ,
#         2.2664342 ,  0.9796524 ,  2.7579641 , -0.8013244 , -0.06382745,
#        -1.6876118 , -0.5075493 , -3.350127  ,  3.765436  , -1.7565534 ,
#        -3.9128711 , -1.1850036 , -2.7939792 , -4.119713  ,  2.2746916 ,
#        -0.2443712 ,  0.971999  ,  0.8746808 ,  1.1469086 ,  0.69436073,
#         1.7989085 ,  2.757239  ,  0.87739575,  2.0527072 ,  0.49560064,
# ...

# %%
model.wv.similarity('arya','sansa')
# Out:
# np.float32(0.85655963)

# %%
model.wv.similarity('cersei','sansa')
# Out:
# np.float32(0.7333864)

# %%
model.wv.similarity('tywin','sansa')
# Out:
# np.float32(0.21631186)

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.12313492, -0.13059172,  0.2138064 , ..., -0.02411233,
#         -0.06641749,  0.1182915 ],
#        [-0.00315592, -0.16826972,  0.10801601, ..., -0.15730281,
#         -0.21977882,  0.21849051],
#        [ 0.10371693, -0.10580768, -0.10160008, ..., -0.0382759 ,
#          0.10862201, -0.07699274],
#        ...,
#        [ 0.05538438,  0.01040661, -0.08380789, ..., -0.00078262,
#          0.10641856, -0.03293372],
#        [ 0.0209311 ,  0.02348985,  0.03914912, ...,  0.06077792,
#         -0.05584021, -0.0467464 ],
#        [-0.00106349, -0.15065083, -0.12243607, ...,  0.16749632,
#         -0.11275666,  0.0912374 ]], dtype=float32)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'lord',
#  'them',
#  'no',
#  'from',
#  'would',
#  'were',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'we',
#  'could',
#  'are',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'did',
#  'by',
#  'king',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'who',
#  'down',
#  'well',
#  'than',
#  'only',
#  'like',
#  'jon',
#  'some',
#  'father',
#  'old',
#  'hand',
#  'even',
#  'too',
#  'tyrion',
#  'before',
#  'never',
#  'an',
#  'off',
#  'know',
#  'see',
#  'into',
#  'made',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'can',
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (17453, 3)

# %%
import plotly.express as px
fig = px.scatter_3d(X[200:300],x=0,y=1,z=2, color=y[200:300])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
