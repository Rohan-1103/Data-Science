# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/session_16_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
empty_series = pd.Series()
empty_series
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
series1 = pd.Series([1, 3, 5, 7, 9])
series2 = pd.Series([0, 2, 4, 6, 8])

sum = series1 + series2
print(sum)

sub = series1 - series2
print(sub)

mul = series1 * series2
print(mul)

div = series1 / series2
print(div)
# Out:
# 0     1
# 1     5
# 2     9
# 3    13
# 4    17
# dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64
# 0     0
# 1     6
# 2    20
# 3    42
# 4    72
# dtype: int64
# 0         inf
# 1    1.500000
# 2    1.250000
# 3    1.166667
# 4    1.125000
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
print(series1 == series2)
print(series1 < series2)

comparision = series1 >= series2
print(comparision)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# pd.to_numeric?

# %%
series = pd.Series([1, 2, 'Python', 2.0, True, 100])
series
# Out:
# 0         1
# 1         2
# 2    Python
# 3       2.0
# 4      True
# 5       100
# dtype: object

# %%
def change_type(ser, datype):
  # return pd.to_numeric(ser, errors='coerce', downcast=datype)
  return pd.to_numeric(ser, errors='coerce')

changed = change_type(series, float)
print(changed)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
np.squeeze?

# %%
runs_data = pd.read_csv('/content/batsman_runs_series.csv', index_col="batter").squeeze()
runs_data
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
amazing_players = runs_data[runs_data > 3000].count()
amazing_players
# Out:
# np.int64(20)

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
above_avg = runs_data[runs_data > runs_data.mean()].count()
above_avg
# Out:
# np.int64(128)

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
from re import X
items_data = pd.read_csv('/content/items.csv', index_col="item_name").squeeze()
# i
print(items_data)
# ii
print(items_data.isna().sum())
# iii
def to_rupees(data):
  try:
    y = data[1:]
  except:
    y = X
  return float(y) * 88.57

items_in_rupees = items_data.apply(to_rupees)
print(items_in_rupees)
# iv
items_in_rupees.fillna(items_in_rupees.mean())
print(items_in_rupees)

items_in_rupees.isna().sum()
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object
# 50
# item_name
# Chips and Fresh Tomato Salsa              211.6823
# Izze                                      300.2523
# Nantucket Nectar                          300.2523
# Chips and Tomatillo-Green Chili Salsa     211.6823
# Chicken Bowl                             1503.9186
#                                            ...
# Steak Burrito                            1040.6975
# ...

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
items_in_rupees.mean()
# Out:
# np.float64(715.1707482907832)

# %%
print(np.percentile(items_in_rupees, 30))
print(np.percentile(items_in_rupees, 6))
# Out:
# 394.1365
# 110.71249999999999

# %%
items_in_rupees.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>
