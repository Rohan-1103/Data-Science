# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/importing_api_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import requests

url = "https://therundown-therundown-v1.p.rapidapi.com/sports/1/conferences"

headers = {
	"x-rapidapi-key": "7cc1dae28dmsh479119308cd5910p17bdf4jsndc3de4962a7b",
	"x-rapidapi-host": "therundown-therundown-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'conferences': [{'conference_id': 91, 'division_id': 1, 'sport_id': 1, 'name': 'Atlantic Coast Conference'}, {'conference_id': 731, 'division_id': 1, 'sport_id': 1, 'name': 'Big 12 Conference'}, {'conference_id': 88, 'division_id': 1, 'sport_id': 1, 'name': 'Big Ten Conference'}, {'conference_id': 766, 'sport_id': 1, 'name': 'SEC - East'}, {'conference_id': 760, 'sport_id': 1, 'name': 'SEC - West'}, {'conference_id': 86, 'division_id': 1, 'sport_id': 1, 'name': 'Southeastern Conference'}, {'conference_id': 85, 'division_id': 1, 'sport_id': 1, 'name': 'Pac-12 Conference'}, {'conference_id': 93, 'division_id': 1, 'sport_id': 1, 'name': 'Conference USA'}, {'conference_id': 772, 'sport_id': 1, 'name': 'Mid-American - East'}, {'conference_id': 771, 'sport_id': 1, 'name': 'Mid-American - West'}, {'conference_id': 84, 'division_id': 1, 'sport_id': 1, 'name': 'Mid-American Conference'}, {'conference_id': 750, 'division_id': 4, 'sport_id': 1, 'name': 'Western Athletic Conference'}, {'confere
# ...

# %%
df = pd.DataFrame(response.json()['conferences'])[['conference_id','division_id','sport_id','name']]
df
# Out:
#      conference_id  division_id  sport_id                       name
# 0               91          1.0         1  Atlantic Coast Conference
# 1              731          1.0         1          Big 12 Conference
# 2               88          1.0         1         Big Ten Conference
# 3              766          NaN         1                 SEC - East
# 4              760          NaN         1                 SEC - West
# ..             ...          ...       ...                        ...
# 96             780          5.0         1                   Piedmont
# 97             781          6.0         1                 Northwoods
# 98             782          6.0         1                    Skyline
# 99             783          5.0         1  South Atlantic Conference
# 100            786          5.0         1       Conference Carolinas
#
# [101 rows x 4 columns]

# %%
df.to_csv('conferences.csv', index=False)
