# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/session_27_fetch_from_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     25.7269
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     22.1828
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     12.6223
# 3  The true story of how businessman Oskar Schind...   1993-12-15     11.9193
# 4  The defense and the prosecution have rested an...   1957-04-10      9.2507
#
#    vote_average  vote_count
# 0         8.700       29219
# 1         8.684       22066
# 2         8.571       13338
# 3         8.566       16860
# 4         8.549        9526

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555   13018                 Deception
# 8556   11011               Ri¢hie Ri¢h
# 8557  586592             Come to Daddy
# 8558  460019             Truth or Dare
# 8559  172533          Drinking Buddies
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  As a corporate auditor who works in a number o...   2008-04-24
# 8556  Billionaire heir Richie Rich has it all, inclu...   1994-12-19
# 8557  After receiving a cryptic letter from his estr...   2019-04-25
# 8558  A harmless game of "Truth or Dare" among frien...   2018-04-12
# 8559  Weekend trips, office parties, late night conv...   2013-08-23
#
#       popularity  vote_average  vote_count
# 0        25.7269         8.700       29219
# 1        22.1828         8.684       22066
# 2        12.6223         8.571       13338
# 3        11.9193         8.566       16860
# 4         9.2507         8.549        9526
# ...          ...           ...         ...
# 8555      1.7898         5.900         692
# 8556      5.6431         5.941        2349
# 8557      3.2620         5.940         569
# 8558      4.2225         5.940        4148
# 8559      1.7636         5.940         844
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')

# %% [markdown]
# ### You can create your own datasets on Kaggle using the apis.
#
# - https://rapidapi.com/hub
# - https://www.kaggle.com/
