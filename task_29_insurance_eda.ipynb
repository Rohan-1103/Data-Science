# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-1103/Data-Science/blob/main/task_29_insurance_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perform EDA on below insurance dataset
#
# Link: https://www.kaggle.com/datasets/thedevastator/insurance-claim-analysis-demographic-and-health
#
# Perform All steps of EDA and document conclusions and then perform feature engineering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/insurance_data.csv')
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# 0        No  southeast   1121.87
# 1        No  southeast   1131.51
# 2        No  southeast   1135.94
# 3        No  northwest   1136.40
# 4        No  northwest   1137.01
# ...     ...        ...       ...
# 1335    Yes  northwest  55135.40
# 1336    Yes  northeast  58571.07
# 1337    Yes  northwest  60021.40
# 1338    Yes  southeast  62592.87
# 1339    Yes  southeast  63770.43
#
# [1340 rows x 11 columns]

# %%
# dropping index duplication
df.set_index('index')
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# 0        No  southeast   1121.87
# 1        No  southeast   1131.51
# 2        No  southeast   1135.94
# 3        No  northwest   1136.40
# 4        No  northwest   1137.01
# ...     ...        ...       ...
# 1335    Yes  northwest  55135.40
# 1336    Yes  northeast  58571.07
# 1337    Yes  northwest  60021.40
# 1338    Yes  southeast  62592.87
# 1339    Yes  southeast  63770.43
#
# [1340 rows x 11 columns]

# %%
df.drop(columns='index', inplace=True)
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3   NaN    male  33.3             82      Yes         0     No
# 3             4   NaN    male  33.7             80       No         0     No
# 4             5   NaN    male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# 0     southeast   1121.87
# 1     southeast   1131.51
# 2     southeast   1135.94
# 3     northwest   1136.40
# 4     northwest   1137.01
# ...         ...       ...
# 1335  northwest  55135.40
# 1336  northeast  58571.07
# 1337  northwest  60021.40
# 1338  southeast  62592.87
# 1339  southeast  63770.43
#
# [1340 rows x 10 columns]

# %% [markdown]
# ### General Dataset analysis
# - Small dataset -> 1340 records and 10 Columns(after dropping index column)
# - Minimal Null values -> 5 in age, 2 in region

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PatientID      1340 non-null   int64
#  1   age            1335 non-null   float64
#  2   gender         1340 non-null   object
#  3   bmi            1340 non-null   float64
#  4   bloodpressure  1340 non-null   int64
#  5   diabetic       1340 non-null   object
#  6   children       1340 non-null   int64
#  7   smoker         1340 non-null   object
#  8   region         1337 non-null   object
#  9   claim          1340 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 104.8+ KB

# %%
df.describe()
# Out:
#          PatientID          age          bmi  bloodpressure     children  \
# count  1340.000000  1335.000000  1340.000000    1340.000000  1340.000000
# mean    670.500000    38.078652    30.668955      94.157463     1.093284
# std     386.968991    11.102924     6.106735      11.434712     1.205334
# min       1.000000    18.000000    16.000000      80.000000     0.000000
# 25%     335.750000    29.000000    26.275000      86.000000     0.000000
# 50%     670.500000    38.000000    30.400000      92.000000     1.000000
# 75%    1005.250000    47.000000    34.700000      99.000000     2.000000
# max    1340.000000    60.000000    53.100000     140.000000     5.000000
#
#               claim
# count   1340.000000
# mean   13252.745642
# std    12109.609288
# min     1121.870000
# 25%     4719.685000
# 50%     9369.615000
# 75%    16604.305000
# max    63770.430000

# %%
corr_matrix = df.select_dtypes('number').corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# ### Categorizing columns
#   - **Numerical columns:** age, bmi, bloodpressure, claim, children
#   - **Categorical columns:** gender, diabetic, smoker, region
#   - **Miscellaneous columns:** PatientID

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Numerical Columns:
# - age:
#   - Min = 18, Max = 60, Mean = 38, Median = 38, Mode = 43
#   - 5 Missing values in 1340 values.
#   - Kde plot shows a bimodal distribution, so using mean and median will not be the best way to deal with the missing values.
#   - We can use mode
#   - No outliers found
#
# - bmi:
#   - No missing values in bmi
#   - Min = 16, Max = 53.1, Mean = 30.66, Median = 30.40
#   - Slightly skewed distribution due to outliers, 0.28597245020808587
#   - Few outliers on the higher end of the values:
#     - Handling using natural log transformation made it negatively skewed with same magnitude.
#     - Applied square root transformation which gave better and more symmetric distribution with skewness - 0.017189507954888536
#
# - bloodpressure:
#   - No missing values.
#   - mean - 94.157463, std - 11.434712, min - 80.000000, median - 92.000000, max - 140.000000
#   - Data is positively skewed with skewness - 1.4835342102293079
#   - There are outliers in the bloodpressure according to the bloodpressure.
#   - Upon examining the outlier records, I could find a moderately positive correlation(0.42) between the smokers and high bloodpressure patients.
#
# - claim:
#   - count - 1340.00, mean - 13252.75, std - 12109.61, min - 1121.87, median - 9369.6150, max - 63770.43
#   - Claim is positively skewed with Skew - 1.5167468509489237
#   - There are outliers in the claim column towards the higher side of the range.
#   - Claim is positively correlated to the smokers and bloodpressure.
#
# - children:
#   - No missing values
#   - 6 Unique values of children from 0 to 6, count of each value is below
#     - | Children | Count |
# |----------|-------|
# | 0        | 576   |
# | 1        | 324   |
# | 2        | 240   |
# | 3        | 157   |
# | 4        | 25    |
# | 5        | 18    |
#   - Data is slightly positively skewed.
#   - Has no correlation with any other column.

# %% [markdown]
# ###### age

# %%
# Checking null values
df['age'].isna().sum()
# Out:
# np.int64(5)

# %%
# Percentage of missing values
df['age'].isna().sum()/len(df['age'])*100
# Out:
# np.float64(0.3731343283582089)

# %%
# Visualizing age column to find the best way to fill missing values
df['age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].value_counts().sort_values()
# Out:
# age
# 53.0    15
# 24.0    16
# 18.0    16
# 58.0    17
# 51.0    17
# 54.0    17
# 21.0    18
# 56.0    18
# 52.0    18
# 60.0    21
# 57.0    21
# 59.0    22
# 41.0    24
# 22.0    24
# 20.0    26
# 39.0    26
# 55.0    26
# 23.0    28
# 19.0    29
# 38.0    32
# 25.0    32
# 50.0    32
# 44.0    35
# 33.0    35
# 35.0    36
# 28.0    36
# 42.0    37
# 36.0    37
# 47.0    37
# 31.0    38
# 49.0    38
# 29.0    39
# 34.0    39
# 45.0    40
# 48.0    40
# 37.0    41
# 27.0    41
# 40.0    42
# 32.0    44
# 30.0    44
# 46.0    44
# 26.0    47
# 43.0    50
# Name: count, dtype: int64

# %%
df['age'].mode()
# Out:
# 0    43.0
# Name: age, dtype: float64

# %%
# Using mode to fill the missing values of the age column
# df['age'].fillna(df['age'].mode())
df['age'] = df['age'].fillna(df['age'].mode()[0])

# %% [markdown]
# 🔍 Why are there two names then?
# - `isnull()` comes from older Pandas versions (inspired by R language).
# - `isna()` was introduced later to be more consistent with NumPy (np.isnan).

# %% [markdown]
# ✔ So which one should you use?
#
# ➡️ `isna()` is now recommended, as it matches other functions like:
# - `fillna()`
# - `dropna()`

# %%
df['age'].isna().sum()
# Out:
# np.int64(0)

# %%
df['age'].plot(kind = 'kde')
print(df['age'].skew())
# Out:
# 0.10904878460145875

# %%
df['age'].describe()
# Out:
# count    1340.000000
# mean       38.097015
# std        11.086239
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
df['age'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ###### BMI

# %%
df['bmi'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['bmi'].plot(kind = 'kde')
print(df['bmi'].skew())
# Out:
# 0.28597245020808587

# %%
# Checking whether outliers are true or not
df[df['bmi'] > 46]
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 9            10  30.0    male  53.1             97       No         0     No
# 141         142  46.0    male  50.4             89      Yes         1     No
# 190         191  28.0    male  46.5             94       No         1     No
# 331         332  43.0    male  46.5             83      Yes         2     No
# 464         465  20.0    male  46.5             89       No         3     No
# 579         580  25.0    male  47.5             84      Yes         1     No
# 675         676  49.0  female  48.1             81      Yes         2     No
# 682         683  27.0  female  46.1            106       No         1     No
# 696         697  49.0    male  47.7             88       No         1     No
# 802         803  42.0    male  49.1            109      Yes         0     No
# 814         815  57.0  female  46.7            101      Yes         2     No
# 880         881  28.0  female  46.8            106       No         5     No
# 1299       1300  50.0    male  52.6            110       No         1    Yes
# 1305       1306  57.0  female  46.2             96       No         0    Yes
# 1306       1307  43.0  female  47.6            112      Yes         2    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# 9     northwest   1163.46
# 141   southeast   2438.06
# 190   southeast   2927.06
# 331   southeast   4686.39
# 464   southeast   6435.62
# 579   southeast   8083.92
# 675   northeast   9432.93
# 682   southeast   9549.57
# 696   southeast   9748.91
# 802   southeast  11381.33
# 814   southwest  11538.42
# 880   southeast  12592.53
# 1299  southeast  44501.40
# 1305  southeast  45863.21
# 1306  southwest  46113.51
# 1339  southeast  63770.43

# %%
# applying log transformation to handle outliers
df['bmi_transformed'] = np.sqrt(df['bmi'])
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3  43.0    male  33.3             82      Yes         0     No
# 3             4  43.0    male  33.7             80       No         0     No
# 4             5  43.0    male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim  bmi_transformed
# 0     southeast   1121.87         4.816638
# 1     southeast   1131.51         5.486347
# 2     southeast   1135.94         5.770615
# 3     northwest   1136.40         5.805170
# 4     northwest   1137.01         5.839521
# ...         ...       ...              ...
# 1335  northwest  55135.40         5.958188
# 1336  northeast  58571.07         6.172520
# 1337  northwest  60021.40         5.873670
# 1338  southeast  62592.87         5.513620
# 1339  southeast  63770.43         6.884766
#
# [1340 rows x 11 columns]

# %%
df['bmi_transformed'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['bmi'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['bmi_transformed'].plot(kind = 'kde')
print(df['bmi_transformed'].skew())
# Out:
# 0.017189507954888536

# %% [markdown]
# ###### **bloodpressure**

# %%
df['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
df['bloodpressure'].plot(kind = 'kde')
print("Skew: ", df['bloodpressure'].skew())
# Out:
# Skew:  1.4835342102293079

# %%
df['bloodpressure'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['bloodpressure'] > 120]
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 1147       1148  29.0  female  32.7            128      Yes         2     No
# 1150       1151  55.0  female  27.1            135       No         1     No
# 1152       1153  38.0  female  35.9            128       No         1     No
# 1153       1154  43.0    male  36.8            126       No         2     No
# 1154       1155  31.0    male  23.8            126      Yes         0    Yes
# 1156       1157  46.0  female  23.0            137      Yes         0    Yes
# 1161       1162  22.0    male  22.4            137      Yes         2     No
# 1166       1167  23.0    male  26.7            123      Yes         0    Yes
# 1169       1170  27.0    male  36.7            130       No         1     No
# 1174       1175  44.0  female  29.1            139       No         0    Yes
# 1181       1182  32.0    male  28.6            132       No         0     No
# 1184       1185  45.0  female  36.9            122      Yes         1     No
# 1192       1193  47.0    male  31.7            129      Yes         0    Yes
# 1194       1195  48.0  female  30.2            129      Yes         0    Yes
# 1196       1197  36.0  female  31.4            136      Yes         0    Yes
# 1197       1198  30.0    male  31.1            136       No         0    Yes
# 1202       1203  32.0    male  31.7            125       No         0    Yes
# 1205       1206  20.0    male  34.9            124      Yes         0    Yes
# 1210       1211  25.0    male  30.8            140      Yes         0    Yes
# 1212       1213  56.0  female  31.0            129      Yes         3    Yes
# 1216       1217  34.0  female  36.9            131       No         0    Yes
# 1218       1219  37.0    male  34.4            126       No         0    Yes
# 1220       1221  32.0    male  38.2            135      Yes         0    Yes
# 1225       1226  50.0  female  34.8            140      Yes         2     No
# 1226       1227  46.0    male  35.5            140      Yes         0    Yes
# 1227       1228  48.0  female  33.5            124       No         0    Yes
# 1229       1230  41.0    male  37.6            127      Yes         1    Yes
# 1230       1231  58.0  female  30.8            139       No         0    Yes
# 1238       1239  42.0    male  26.1            131      Yes         1    Yes
# 1239       1240  29.0    male  35.8            124       No         1    Yes
# 1242       1243  27.0  female  36.7            140       No         2    Yes
# 1244       1245  22.0    male  36.3            123       No         2    Yes
# 1245       1246  28.0    male  34.4            137       No         3    Yes
# 1246       1247  25.0  female  42.2            131      Yes         0    Yes
# 1252       1253  37.0    male  30.8            125      Yes         3    Yes
# 1254       1255  46.0    male  44.9            138      Yes         0    Yes
# 1256       1257  27.0    male  30.9            139       No         0    Yes
# 1257       1258  43.0    male  36.7            139      Yes         1    Yes
# 1258       1259  38.0  female  34.8            132       No         2    Yes
# 1268       1269  42.0  female  39.1            131      Yes         3    Yes
# 1270       1271  27.0  female  33.1            128       No         0    Yes
# 1276       1277  20.0    male  38.4            124      Yes         3    Yes
# 1278       1279  35.0  female  35.5            135       No         0    Yes
# 1279       1280  37.0    male  45.5            124      Yes         2    Yes
# 1283       1284  28.0    male  38.1            125      Yes         2    Yes
# 1289       1290  52.0  female  31.2            127       No         0    Yes
# 1290       1291  47.0    male  41.9            140      Yes         3    Yes
# 1292       1293  45.0  female  40.4            123       No         2    Yes
# 1294       1295  36.0  female  30.2            130       No         1    Yes
# 1302       1303  35.0  female  32.5            134      Yes         0    Yes
# 1307       1308  47.0    male  31.4            137       No         3    Yes
# 1315       1316  23.0    male  35.1            121       No         0    Yes
# 1325       1326  52.0  female  36.4            133      Yes         1    Yes
# 1333       1334  44.0    male  36.4            127       No         1    Yes
# 1334       1335  43.0    male  32.8            125       No         0    Yes
#
#          region     claim  bmi_transformed
# 1147  northwest  26018.95         5.718391
# 1150  southwest  26140.36         5.205766
# 1152  northeast  26392.26         5.991661
# 1153  northwest  26467.10         6.066300
# 1154  southeast  26926.51         4.878524
# 1156  southeast  27037.91         4.795832
# 1161  northeast  27375.90         4.732864
# 1166  northeast  28101.33         5.167204
# 1169  northwest  28468.92         6.058052
# 1174  northwest  29141.36         5.394442
# 1181  northeast  30260.00         5.347897
# 1184  northeast  31620.00         6.074537
# 1192  northeast  33732.69         5.630275
# 1194  southwest  33900.65         5.495453
# 1196  southwest  34166.27         5.603570
# 1197  northeast  34254.05         5.576737
# 1202  southeast  34672.15         5.630275
# 1205  southwest  34828.65         5.907622
# 1210  southwest  35491.64         5.549775
# 1212  southeast  35595.59         5.567764
# 1216  southeast  36149.48         6.074537
# 1218  southwest  36197.70         5.865151
# 1220  southeast  36307.80         6.180615
# 1225  southwest  36910.61         5.899152
# 1226  southeast  36950.26         5.958188
# 1227  southwest  37079.37         5.787918
# 1229  southeast  37165.16         6.131884
# 1230  northeast  37270.15         5.549775
# 1238  southeast  38245.59         5.108816
# 1239  southeast  38282.75         5.983310
# 1242  northeast  38511.63         6.058052
# 1244  southwest  38711.00         6.024948
# 1245  northwest  38746.36         5.865151
# 1246  southeast  38792.69         6.496153
# 1252  northeast  39597.41         5.549775
# 1254  southeast  39722.75         6.700746
# 1256  southwest  39727.61         5.558777
# 1257  northeast  39774.28         6.058052
# 1258  southwest  39836.52         5.899152
# 1268  southeast  40932.43         6.252999
# 1270  southeast  40974.16         5.753260
# 1276  southeast  41949.24         6.196773
# 1278  northeast  42111.66         5.958188
# 1279  southeast  42112.24         6.745369
# 1283  southeast  42560.43         6.172520
# 1289  northwest  43578.94         5.585696
# 1290  northeast  43753.34         6.473021
# 1292  southeast  43896.38         6.356099
# 1294  northwest  43943.88         5.495453
# 1302  southeast  45008.96         5.700877
# 1307  northwest  46130.53         5.603570
# 1315  southeast  47055.53         5.924525
# 1325  northeast  48517.56         6.033241
# 1333  southwest  51194.56         6.033241
# 1334  southwest  52590.83         5.727128

# %%
# df['bloodpressure'].corr(df['smoker'])
# df['bloodpressure'].corr(df['smoker'].astype(int))
df['bloodpressure'].corr(df['smoker'].str.strip().str.lower().map({'yes':1,'no':0}))
# Out:
# np.float64(0.41826466954537145)

# %%
df['smoker_bool'] = df['smoker'].str.strip().str.lower().map({'yes':1,'no':0})
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3  43.0    male  33.3             82      Yes         0     No
# 3             4  43.0    male  33.7             80       No         0     No
# 4             5  43.0    male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim  bmi_transformed  smoker_bool
# 0     southeast   1121.87         4.816638            0
# 1     southeast   1131.51         5.486347            0
# 2     southeast   1135.94         5.770615            0
# 3     northwest   1136.40         5.805170            0
# 4     northwest   1137.01         5.839521            0
# ...         ...       ...              ...          ...
# 1335  northwest  55135.40         5.958188            1
# 1336  northeast  58571.07         6.172520            1
# 1337  northwest  60021.40         5.873670            1
# 1338  southeast  62592.87         5.513620            1
# 1339  southeast  63770.43         6.884766            1
#
# [1340 rows x 12 columns]

# %%
corr_matrix = df.select_dtypes('number').corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# ###### claim

# %%
df['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
df['claim'].plot(kind = 'kde')
print('Skew: ', df['claim'].skew())
# Out:
# Skew:  1.5167468509489237

# %%
df['claim'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ###### children

# %%
df['children'].describe()
# Out:
# count    1340.000000
# mean        1.093284
# std         1.205334
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
df['children'].value_counts()
# Out:
# children
# 0    576
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df['children'].plot(kind = 'kde')
print("skew: ", df['children'].skew())
# Out:
# skew:  0.9402991133470963

# %% [markdown]
# #### **Categorical columns:**
#   - gender:
#     - Missing values: None
#     - Unique values: 2
#       - male - 678 (50.60%)
#       - female - 662 (49.40%)
#
#   - diabetic:
#     - Missing values: None
#     - Unique values: 2
#       - No - 698 (52.09%)
#       - Yes - 642 (47.91%)
#
#   - smoker:
#     - Missing values: None
#     - Unique values: 2
#       - No - 1066 (79.55%)
#       - Yes - 274 (20.45%)
#
#   - region:
#     - Missing values: 3
#     - Unique values: 4
#     -  | Region     | Count |
# |------------|-------|
# | Southeast  | 443 (33.13%)   |
# | Northwest  | 349 (26.10%)   |
# | Southwest  | 314 (23.49%)   |
# | Northeast  | 231 (17.28%)   |

# %% [markdown]
# ###### gender

# %%
df['gender'].describe()
# Out:
# count     1340
# unique       2
# top       male
# freq       678
# Name: gender, dtype: object

# %%
# df['gender'].plot(kind = 'pie', autopct = "%0.01f%%")
df['gender'].value_counts().plot(kind='pie', autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ###### diabetic

# %%
df['diabetic'].describe()
# Out:
# count     1340
# unique       2
# top         No
# freq       698
# Name: diabetic, dtype: object

# %%
df['diabetic'].value_counts().plot(kind='pie', autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ###### region

# %%
df['region'].describe()
# Out:
# count          1337
# unique            4
# top       southeast
# freq            443
# Name: region, dtype: object

# %%
df['region'].value_counts()
# Out:
# region
# southeast    443
# northwest    349
# southwest    314
# northeast    231
# Name: count, dtype: int64

# %%
df['region'].value_counts().plot(kind='pie', autopct='%0.02f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ###### smoker

# %%
df['smoker'].describe()
# Out:
# count     1340
# unique       2
# top         No
# freq      1066
# Name: smoker, dtype: object

# %%
df['smoker'].value_counts().plot(kind='pie', autopct='%0.02f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Numerical to Numerical:
# - bmi vs bloodpressure:
#   - With the visualization it is seen that patients with bmi lower than 25 generally have lower bloodpressure.
#
# - claim vs bloodpressure:
#   - Patients with bloodpressure higher than 110 have claimed amount above 20000.

# %% [markdown]
# ###### bmi vs bloodpressure

# %%
# df['bmi'].plot(kind = 'kde')
# df['bloodpressure'].plot(kind = 'kde')

# NOT GOOD

# %%
sns.regplot(data = df, x = 'bmi', y = 'bloodpressure')
# Out:
# <Axes: xlabel='bmi', ylabel='bloodpressure'>

# %%
sns.jointplot(x='bmi', y='bloodpressure', data=df, kind='kde')

# %%
plt.hexbin(df['bmi'], df['bloodpressure'], gridsize=25)

# %% [markdown]
# ###### claim vs bloodpressure

# %%
sns.regplot(data = df, x = 'bloodpressure', y = 'claim')
# Out:
# <Axes: xlabel='bloodpressure', ylabel='claim'>

# %%
plt.hexbin(df['bloodpressure'], df['claim'], gridsize=25)
plt.colorbar()

# %% [markdown]
# #### Numerical to Categorical
#   - bloodpressure vs smoker:
#     - with the help of point plot we can clearly see that smokers have higher bloodpressure compared to non smokers.
#
#   - claim vs smoker:
#     - smokers have higher claim amounts compared to non smokers.

# %% [markdown]
# ###### bloodpressure vs smoker

# %%
# sns.displot(data = df, x = 'smoker', y = 'bloodpressure', kind='kde')
sns.catplot(data = df, x = 'smoker', y = 'bloodpressure', kind = 'point')

# %%
sns.catplot(data = df, kind = 'violin', x = 'smoker', y = 'bloodpressure')

# %%
sns.catplot(data = df, kind = 'violin', y = 'bloodpressure', hue = 'smoker', split = True)

# %% [markdown]
# ###### claim vs smoker

# %%
sns.catplot(data = df, kind = 'strip', x = 'smoker', y = 'claim')

# %%
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3  43.0    male  33.3             82      Yes         0     No
# 3             4  43.0    male  33.7             80       No         0     No
# 4             5  43.0    male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim  bmi_transformed  smoker_bool
# 0     southeast   1121.87         4.816638            0
# 1     southeast   1131.51         5.486347            0
# 2     southeast   1135.94         5.770615            0
# 3     northwest   1136.40         5.805170            0
# 4     northwest   1137.01         5.839521            0
# ...         ...       ...              ...          ...
# 1335  northwest  55135.40         5.958188            1
# 1336  northeast  58571.07         6.172520            1
# 1337  northwest  60021.40         5.873670            1
# 1338  southeast  62592.87         5.513620            1
# 1339  southeast  63770.43         6.884766            1
#
# [1340 rows x 12 columns]

# %% [markdown]
# #### Categorical to Categorical
# - Gender vs Diabetic:
#   - Number of diabetic patients are almost same for male and female.
# - Gender vs Smoker:
#   - Higher number of female non smokers compared to male non smokers.

# %% [markdown]
# ###### gender vs diabetic

# %%
pd.crosstab(df['gender'], df['diabetic']).plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# ###### gender vs smoker

# %%
sns.heatmap(pd.crosstab(df['gender'], df['smoker']))
# Out:
# <Axes: xlabel='smoker', ylabel='gender'>

# %%
pd.crosstab(df['gender'], df['smoker']).plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='gender'>

# %%
from statsmodels.graphics.mosaicplot import mosaic

# %%
mosaic(df, ['gender', 'smoker'], title="Gender vs Smoker", gap=0.02)
plt.show()
